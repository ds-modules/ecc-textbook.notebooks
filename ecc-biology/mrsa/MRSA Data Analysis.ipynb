# %% [raw]
# # ASSIGNMENT CONFIG
# generate:
#     pdf: true
# files:
#     - ca_map.png
#     - census_bonus.csv
#     - infec_pop_merge.csv
#     - mrsa_2013.csv
#     - mrsa_merged.csv
#     - mrsa-in-hospitals-2013.csv
#     - widgets.py

# %% [markdown]
# # MRSA Data Analysis
# ### Professor Polly Parks

# %% [markdown]
# **Estimated Time**: 30-40 minutes <br>
# **Databook created by**: Rucha Kelkar, Harry Li, Elias Saravia, Ariana Ghimire

# %% [markdown]
# Hi everyone! My name is Ariana, and I’m part of a team at UC Berkeley that builds interactive data science notebooks for community college students. Our goal is to make data science more accessible by connecting it with real-world topics across different fields—like biology, public health, economics, and ethnic studies. By combining data analysis with domain knowledge, we hope to show how computational tools can help answer meaningful questions.
#
# ### About This Notebook
# Today we will be examining a dataset (a table of data) and several graphs related to Methicillin-resistant *Staphylococcus aureus* (MRSA), a bacterial infection that can cause serious illness. In this notebook, you’ll analyze patterns in the data and use your knowledge of immunity and infectious disease to draw conclusions about how MRSA spreads and affects populations.
#
# Because this version of the notebook is designed for students who already have some programming experience, we’ll also use this as an opportunity to connect basic coding and data skills to clinical questions. You’ll work with Jupyter Notebooks (the platform you are currently using) and Python (a programming language) to explore the dataset, interpret visualizations, and practice thinking like both a clinician and a data scientist.
#
# While the notebook will briefly review key tools, it will also give you a bit more independence to explore the data and develop your own insights.

# %% [markdown]
# ### Table of Contents
# 1. [Intro to Jupyter](#0) <br>
# 1. [Intro to MRSA](#2) <br>
# 1. [Intro to Dataset](#3) <br>
# 1. [Comparing Infection Rates Over Time](#4) <br>
# 1. [Comparing County Infection Rates with County Populations](#5) <br>
# 1. [Exploring Census Data by County, Year, and Race](#6)
# 1. [Download PDF to submit work](#8)

# %% [markdown]
# # 1. Intro to Jupyter <a id='0'></a>
#
# This webpage is a Jupyter Notebook. Jupyter Notebooks run on the Python coding language and provides an interactive interface for students. We will use this notebook to analyze a dataset on MRSA bloodstream infections in California hospitals. Jupyter Notebooks are composed of both regular text and code cells. Code cells have a gray background. In order to run a code cell, click the cell and press Shift + Enter while the cell is selected or hit the ▶| Run button in the toolbar at the top. You can also save your work using the button on the top left hand corner. In a Jupyter Notebook, the **kernel** is the background process that runs and remembers all the code you execute. If certain libraries are imported in a different order, it can affect how widgets and plots behave. You can also restart the kernel by clicking **Kernel → Restart Kernel** in the top right menu of the Jupyter Notebook.
#
# An example of a code cell is shown below. The contents of this cell set up the notebook by importing pre-written Python packages that we will be using to read in, clean, analyze, and model our data. Run it, and once it is done, you should see "Done!" printed underneath the cell.

# %%
## DO NOT DELETE ANYTHING IN THIS CELL ##
# %pip install otter-grader numpy pandas datascience matplotlib ipywidgets notebook
# import utilities
import os
from pathlib import Path

from otter import Notebook
import numpy as np
import pandas as pd
from datascience import *
import matplotlib.pyplot as plt
import ipywidgets as widgets

# Make relative data-file paths work even if Jupyter starts in the project root.
for candidate_dir in [Path.cwd().resolve(), *Path.cwd().resolve().parents]:
    if (candidate_dir / "mrsa_merged.csv").exists():
        os.chdir(candidate_dir)
        break
else:
    raise FileNotFoundError(
        "Could not locate 'mrsa_merged.csv'. Open the notebook from the project folder or the 'mrsa' folder."
    )

widgets.IntSlider()
print("Done!")
# Out:
# Requirement already satisfied: otter-grader in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (6.1.6)
# Requirement already satisfied: numpy in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (2.4.2)
# Requirement already satisfied: pandas in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (3.0.0)
# Requirement already satisfied: datascience in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (0.18.1)
# Requirement already satisfied: matplotlib in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (3.10.8)
# Requirement already satisfied: ipywidgets in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (8.1.8)
# Requirement already satisfied: notebook in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (7.5.5)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (8.3.1)
# Requirement already satisfied: dill>=0.3.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (0.4.1)
# Requirement already satisfied: fica>=0.4.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (0.4.1)
# Requirement already satisfied: ipylab<2.0.0,>=1.0.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (1.1.0)
# Requirement already satisfied: ipython in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (9.10.0)
# Requirement already satisfied: jinja2<4.0,>=3.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (3.1.6)
# Requirement already satisfied: jupytext<2.0.0,>=1.16.4 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (1.19.1)
# Requirement already satisfied: nbconvert>=6.0.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (7.17.0)
# Requirement already satisfied: nbformat>=5.0.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (5.10.4)
# Requirement already satisfied: python-on-whales<1.0.0,>=0.72.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (0.80.0)
# Requirement already satisfied: pyyaml<7,>=6 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (6.0.3)
# Requirement already satisfied: requests<3.0,>=2.31 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (2.32.5)
# Requirement already satisfied: wrapt<2.0.0,>=1.16.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from otter-grader) (1.17.3)
# Requirement already satisfied: comm>=0.1.3 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jinja2<4.0,>=3.1->otter-grader) (3.0.3)
# Requirement already satisfied: markdown-it-py>=1.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupytext<2.0.0,>=1.16.4->otter-grader) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupytext<2.0.0,>=1.16.4->otter-grader) (0.5.0)
# Requirement already satisfied: packaging in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupytext<2.0.0,>=1.16.4->otter-grader) (26.0)
# Requirement already satisfied: pydantic!=2.0.*,<3,>=2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from python-on-whales<1.0.0,>=0.72.0->otter-grader) (2.12.5)
# Requirement already satisfied: typing-extensions in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from python-on-whales<1.0.0,>=0.72.0->otter-grader) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from pydantic!=2.0.*,<3,>=2->python-on-whales<1.0.0,>=0.72.0->otter-grader) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from requests<3.0,>=2.31->otter-grader) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from requests<3.0,>=2.31->otter-grader) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from requests<3.0,>=2.31->otter-grader) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from requests<3.0,>=2.31->otter-grader) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: folium>=0.9.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from datascience) (0.20.0)
# Requirement already satisfied: setuptools in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from datascience) (82.0.0)
# Requirement already satisfied: scipy in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from datascience) (1.17.0)
# Requirement already satisfied: plotly in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from datascience) (6.5.2)
# Requirement already satisfied: branca in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from datascience) (0.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from notebook) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.6 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from notebook) (4.5.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from notebook) (6.5.4)
# Requirement already satisfied: anyio>=3.1.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (2.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (7.2.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyterlab<4.6,>=4.5.6->notebook) (2.3.0)
# Requirement already satisfied: httpcore==1.* in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.6->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: docutils in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from fica>=0.4.1->otter-grader) (0.22.4)
# Requirement already satisfied: sphinx in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from fica>=0.4.1->otter-grader) (9.1.0)
# Requirement already satisfied: xyzservices in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from folium>=0.9.1->datascience) (2025.11.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (1.8.20)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook) (7.2.2)
# Requirement already satisfied: decorator>=4.3.2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipython->otter-grader) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipython->otter-grader) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipython->otter-grader) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipython->otter-grader) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipython->otter-grader) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipython->otter-grader) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from ipython->otter-grader) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->otter-grader) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jedi>=0.18.1->ipython->otter-grader) (0.8.6)
# Requirement already satisfied: attrs>=22.2.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.5.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (25.10.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from markdown-it-py>=1.0->jupytext<2.0.0,>=1.16.4->otter-grader) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (1.5.1)
# Requirement already satisfied: webencodings in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (1.4.0)
# Requirement already satisfied: playwright in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (1.58.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from nbformat>=5.0.0->otter-grader) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from pexpect>4.3->ipython->otter-grader) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython->otter-grader) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython->otter-grader) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython->otter-grader) (0.2.3)
# Requirement already satisfied: cffi>=2.0.0b1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from cffi>=2.0.0b1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from beautifulsoup4->nbconvert>=6.0.0->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: tzdata in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.3)
# Requirement already satisfied: pyee<14,>=13 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from playwright->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from playwright->nbconvert[webpdf]>=6.0.0; sys_platform != "emscripten" and sys_platform != "wasi"->otter-grader) (3.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from plotly->datascience) (2.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (3.0.1)
# Requirement already satisfied: alabaster>=0.7.14 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (1.4.1)
# Requirement already satisfied: roman-numerals>=1.0.0 in /Users/arianaghimire/Desktop/ecc-biology/.venv/lib/python3.14/site-packages (from sphinx->fica>=0.4.1->otter-grader) (4.1.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Done!

# %% [markdown]
# <br><br>
# ### 1.1 Common errors and how to fix them
#
# ##### Accidentally deleted something in a cell?
# Double click on that cell and press Ctrl+Z or Command+Z until you recover the deleted information. Otherwise, ask your GSI for help.
#
# ##### Getting a really long error message?
# This could be a result of deleting code somewhere in the notebook in a code cell. If you remember which cell you deleted code from, double click on that cell and press Ctrl+Z or Command+Z until the code is as it was originally. Otherwise, raise your hand and ask for help from your GSI.
#
# ##### Getting the error 'data_frame' not present?
# Make sure you have all of the relevant data files in the same folder as this notebook (mrsa_merged.csv, infec_pop_merge.csv, mrsa_2013.csv, mrsa-in-hospitals-2013.csv, census_bonus.csv) and that widgets.py is in the same folder.
#
# ##### Something is running for too long?
# Try restarting the kernel. Sometimes Jupyter might be overloaded with the simplest of commands. Don't worry, just save your work and restart the kernel.
#
# ##### Getting multiple plots in the widgets below?
# This happened because you ran the line `from datascience import *`  before working with the plot widgets. Try restarting the kernel and making sure you finish your work with the plot widgets BEFORE running the code cell with the aforementioned line.

# %% [markdown]
# ---

# %% [markdown]
# # 2. Intro to MRSA <a id='2'></a>

# %% [markdown]
# MRSA, or methicillin resistant S. auereus, is one example of a bacteria that is highly resistant to antibiotics. It is usually a hospital acquired infection though it can also be spread through the community. A review of 15 studies showed that 13-74% of all *S. aureus* infections are MRSA. For future nurses, this matters because MRSA infections change the kinds of precautions you take, the antibiotics that are ordered, and how closely you monitor patients for complications. Managing this infection requires careful indentification of the MRSA strain and source of infection, proper choice of antibiotics, and robust prevention strategies. Active surveillance of personnel and disinfection of healthcare equipment and rooms is critical for prevention. For more information on MRSA, refer back to you professor's lecture slides on this topic.

# %% [raw]
# # BEGIN QUESTION
# name: q1
# manual: true

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### Discussion Question 1:
# **From what you know about MRSA and our class content, where do you think the majority of MRSA cases are located in California (urban counties vs. rural counties)?**
#
# **How could a difference in population density affect the total number of MRSA infections?**
#
# **What possible downstream connections can be made in relation to the workload for nurses and other healthcare staff?**

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# REPLACE THIS TEXT WITH YOUR RESPONSE
# <br> [Note: double click on the cell, type in your response, and run the cell to save your work]

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---

# %% [markdown]
# # 3. Intro to Data <a id='3'></a>

# %% [markdown]
# ### 3.1 Reading in Data Sets
#
# We will be analyzing is the Methicillin-resistant Staphylococcus aureus (MRSA) bloodstream infections (BSI) in California Hospitals data from the [California Health and Human Services Agency](https://data.chhs.ca.gov/dataset/methicillin-resistant-staphylococcus-aureus-mrsa-bloodstream-infections-bsi-in-california-hospitals).
#
# > California Health and Safety Code section 1288.55(a)(1) requires general acute care hospitals to report all cases of Methicillin-resistant Staphylococcus aureus (MRSA) bloodstream infections (BSI) identified in their facilities to the California Department of Public Health (CDPH). MRSA BSI data are submitted by hospitals to the Centers for Disease Control and Prevention National Healthcare Safety Network (NHSN). CDPH downloads California hospital MRSA BSI data from NHSN and analyzes the data to describe prevention progress in an annual public report of healthcare-associated infections. CDPH publishes annual MRSA BSI data reported by each California hospital in the datasets below.
#
# Run the code cell below to load the data that we will be using for analysis.

# %%
# This cell will read in the necessary data sets. Run it and take a look at the dataframes below!
mrsa_merged = pd.read_csv('mrsa_merged.csv') #merged mrsa data
infec_pop_merge = pd.read_csv('infec_pop_merge.csv') #combined mrsa and population data

print("Done!")
# Out:
# Done!

# %% [markdown]
# ### 3.2 Understanding the Data

# %% [markdown]
# Let's visualize the raw data of MRSA Reports in 2013. Data is usually recorded in a dataset (or table) format with rows and columns. Each row represents a distinct observation and each column represents a feature/variable. Run the code cell below to see the dataset. You can scroll horizontally to see all of the columns that are included.

# %%
mrsa_2013_raw = pd.read_csv('mrsa-in-hospitals-2013.csv') #raw data
mrsa_2013_raw.head()
# Out:
#    Year        State                                                HAI  \
# 0   2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
# 1   2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
# 2   2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
# 3   2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
# 4   2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
#
#                                   Facility_Name1  \
# 0              Adventist Medical Center, Hanford
# 1              Adventist Medical Center, Reedley
# 2  AHMC Anaheim Regional Medical Center, Anaheim
# 3         Alameda County Medical Center, Oakland
# 4                               Alameda Hospital
#
#                                       Facility_Name2 Facility_Name3  \
# 0                     Adventist Medical Center-Selma              .
# 1                                                  .              .
# 2                                                  .              .
# 3  Alameda County Medical Center-Fairmont Campus,...              .
# 4                                                  .              .
#
#       FACID1     FACID2 FACID3        County  Infection_Count  Patient_Days  \
# 0   40000122  630012960      .  Kings-Fresno              2.0       42875.0
# 1   40000124          .      .        Fresno              0.0        5970.0
# 2   60000002          .      .        Orange              3.0       51929.0
# 3  140000034  140000184      .       Alameda              7.0       55590.0
# 4  140000011          .      .       Alameda              0.0       11520.0
#
#    SIR   SIR_95%_CI_Lower_Limit  SIR_95%_CI_Upper_Limit    Comparison  \
# 0  0.76                    0.13                    2.50  No Different
# 1   NaN                     NaN                     NaN             .
# 2  1.15                    0.29                    3.13  No Different
# 3  2.09                    0.91                    4.12  No Different
# 4  0.00                    0.00                    2.88  No Different
#
#                     Notes
# 0  †  See Data Dictionary
# 1                     NaN
# 2                     NaN
# 3  †  See Data Dictionary
# 4                     NaN

# %% [markdown]
# Shown above are the first five rows of the the data table. As you can see, there are a lot of columns as well as a lot of missing information in some of the columns. We have cleaned the data for you by removing any unncessary features and renaming the columns to make their purpose more clear. Run the code cell below to see the cleaned data set from MRSA Reports in 2013 below.

# %%
mrsa_2013 = pd.read_csv('mrsa_2013.csv') #cleaned data
mrsa_2013.head()
# Out:
#    Year       State                                                HAI  \
# 0  2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
# 1  2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
# 2  2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
# 3  2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
# 4  2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
#
#                                        Facility1  Facility1_ID       County  \
# 0              Adventist Medical Center, Reedley      40000124       Fresno
# 1  AHMC Anaheim Regional Medical Center, Anaheim      60000002       Orange
# 2         Alameda County Medical Center, Oakland     140000034      Alameda
# 3                               Alameda Hospital     140000011      Alameda
# 4               Alhambra Hospital Medical Center     930000005  Los Angeles
#
#    Infection_Count  Num_patients
# 0              0.0        5970.0
# 1              3.0       51929.0
# 2              7.0       55590.0
# 3              0.0       11520.0
# 4              0.0       19433.0

# %% [markdown]
# ---

# %% [markdown]
# ### 3.3 Breaking down the table

# %% [markdown]
# #### 3.3.1 Rows
#
# Let's take a look at the first row of the dataset for MRSA Reports in 2013.

# %%
mrsa_2013.take([0])
# Out:
#    Year       State                                                HAI  \
# 0  2013  California  Methicillin-Resistant Staphylococcus aureus Bl...
#
#                            Facility1  Facility1_ID  County  Infection_Count  \
# 0  Adventist Medical Center, Reedley      40000124  Fresno              0.0
#
#    Num_patients
# 0        5970.0

# %% [markdown]
# This particular row in our data represents a 2013 report representing the number of MRSA infections recorded in the Adventist Medical Center, Reedley in the Fresno County.
#
# Therefore, in general, every row in our dataset represents a distinct MRSA report from a California hospital in 2013.
#
# Try analyzing another row, just change the number `0` in the above code cell to see that numbered row. Since there are only 352 rows in our table, be sure your number is less than 352.

# %% [markdown]
# #### 3.3.2. Columns
# Run the code cell below to see the list of the columns in our dataset.

# %%
mrsa_2013.columns.tolist()
# Out:
# ['Year',
#  'State',
#  'HAI',
#  'Facility1',
#  'Facility1_ID',
#  'County',
#  'Infection_Count',
#  'Num_patients']

# %% [raw]
# # BEGIN QUESTION
# name: q2
# manual: true

# %% [markdown]
# Take a look at the columns names of the table listed above. Most of the columns should be pretty self-explanatory. For those that aren't,
# - **HAI:** Hospital Acquired Infection. This refers to MRSA infections in hospital patients only.
# - **Facility1:** the name of the specific medical center/hospital.
# - **Facility1_ID:** a unique number identifier for the medical facility.

# %% [markdown]
# ### Discussion Question 2:
# **Of the questions we asked about MRSA, which are actually answerable given this dataset? Which questions could be answerable with a different dataset? And which would be hard to answer with the data we gave you?**

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# REPLACE THIS TEXT WITH YOUR RESPONSE
# <br> [Note: double click on the cell, type in your response, and run the cell to save your work]

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---

# %% [markdown]
# # 4. Comparing Infection Rates Over Time <a id='4'></a>
#
# Previously, we were looking at the MRSA infections in hospitals in 2013. Now, we combined multiple datasets for MRSA Reports from 2013 - 2018. Our goal in analyzing this dataset is to see how the infection rates have changed over time across counties.
#
# Use the plot widget to answer the discussion question below. Run the code cell below and toggle through the drop-down menu to look at infection counts for different counties.

# %%
from widgets import infection_rates_per_county
# %matplotlib inline
infection_rates_per_county()
# Out:
# interactive(children=(Dropdown(description='County', options=('Fresno', 'Orange', 'Alameda', 'Los Angeles', 'S…

# %% [raw]
# # BEGIN QUESTION
# name: q3
# manual: true

# %% [markdown]
# ### Discussion Question 3:
# **Choose one urban county (e.g. Los Angeles) and one rural county (e.g. Sonoma) to evaluate. What trends can you identify? What outliers do you see? Make a general statement on how MRSA infections have changed over time in these two counties.**

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# REPLACE THIS TEXT WITH YOUR RESPONSE
# <br> [Note: double click on the cell, type in your response, and run the cell to save your work]

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---

# %% [markdown]
# # 5. Comparing County Infection Rates with County Populations <a id='5'></a>

# %% [markdown]
# ### 5.1 Infection rate by county per year
#
# We can use the same data to compare the infection rates based on the population within a county. A question we can ask is: What is the trend over the years of total population against infection counts?
#
# The following code cell displays a widget that plots a regression (best fit) line over these two variables. See if you can catch an interesting trend.

# %%
from widgets import population_v_infection_by_county
population_v_infection_by_county()
# Out:
# interactive(children=(Dropdown(description='County', options=('Alameda', 'Amador', 'Butte', 'Calaveras', 'Colu…

# %% [raw]
# # BEGIN QUESTION
# name: q4
# manual: true

# %% [markdown]
# ### Discussion Question 4:
#
# **Look at the same two urban and rural counties that you chose for the previous question. What information can you draw from the above graph for those two counties?**

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# REPLACE THIS TEXT WITH YOUR RESPONSE
# <br> [Note: double click on the cell, type in your response, and run the cell to save your work]

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---

# %% [markdown]
# ### 5.2 Infection rate across counties by year
#
# The last portion of our analysis will be to look at infection counts across all counties each year. We calculate a "best fit" regression line to estimate the rate of infection.
#
# Run the code cell below to load the widget. Feel free to select different years to see the change in slopes.

# %%
from widgets import population_vs_infection_by_year
population_vs_infection_by_year()
# Out:
# interactive(children=(Dropdown(description='Year', options=(2013, 2014, 2015, 2016, 2017, 2018), value=2013), …

# %% [raw]
# # BEGIN QUESTION
# name: q5
# manual: true

# %% [markdown]
# ### Discussion Question 5:
#
# **Select different years in the graph above. What do you notice about the slope across different years? What information can you draw from the graph above?**

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# REPLACE THIS TEXT WITH YOUR RESPONSE
# <br> [Note: double click on the cell, type in your response, and run the cell to save your work]

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---

# %% [markdown]
# ### 5.3 California Counties Colored by Infection Rate (number of infections/population)
#
# We can also use maps to gain more insight from the data.
#
# A choropleth map (from Greek χῶρος "area/region" and πλῆθος "multitude") is a type of thematic map in which areas are shaded or patterned in proportion to a statistical variable that represents an aggregate summary of a geographic characteristic within each area, such as population density or per-capita income.
#
# Below is a a **chloropleth map**, which is similar to a heat map where color schemes in areas communicate high values with bright colors and low values with darker colors. For example, a [weather map](https://www.google.com/search?q=weather+map&hl=en&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjdhcDEhbLoAhWM4J4KHX2aCLoQ_AUoAXoECA0QAw&biw=1440&bih=821#imgrc=OmR67PwUq48WEM) shows high temperature in red and colder temperature in blue. This map shows each California County and the rate of infection per unit of population (100,000 people). The darker red the county, the higher its MRSA infection rate is. The colorbar on the right side of the map shows the range of infection rates. Take a look at the map below and use it to answer the discussion question below.

# %% [markdown]
# <img src="ca_map.png" style="width: 1200px;"/>

# %% [raw]
# # BEGIN QUESTION
# name: q6
# manual: true

# %% [markdown]
# ### Discussion Question 6:
# **Having looked at the chloropleth map of California counties above, what trends/outliers do you see? Find your two chosen urban and rural counties from previous questions. Are the MRSA infection rates (denoted by color) consistent with what you originally thought? What would you say overall about the relationship between infection rates and population?**

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# REPLACE THIS TEXT WITH YOUR RESPONSE
# <br> [Note: double click on the cell, type in your response, and run the cell to save your work]

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# ---

# %% [markdown]
# # 6. Exploring Census Data by County, Year, and Race <a id='6'></a>
#
# Our datasets also include **California Census population data**. Each row contains:
# - The **year** and **county**.
# - The **total population**.
# - Breakdowns of the population by **race** and **sex**.
#
# In this section, you will:
#
# 1. Review how a **group by** operation works.
# 2. Look at a table thats grouped by year and county.
# 3. Use simple code (no widgets) to:
#    - Focus on one county across years.
#    - Make at least one plot that compares total population or a specific race group over time.
#    - Interpret what you see from a public‑health / nursing perspective.

# %% [markdown]
# ### 6.1 Quick review: what does **group by** mean?
#
# A **group by** operation answers questions like:
#
# - “What is the total MRSA infection count **per year**?”
# - “What is the total population **per county**?”
#
# In plain language, you:
#
# 1. **Choose a column (or columns) to group by** (for example, `Year`).
# 2. **Combine all rows that share the same values** in those columns.
# 3. **Apply a summary function** (often `sum`, `mean`, or `count`) to the numeric columns.
#
# In the code below, use the group operation to group by 'Year' and 'County' and apply the function 'sum'. Once you have gone through this section once, feel free to mix up vairble/operation.
#
# <details>
# <summary><strong>HINT:</strong></summary>
#
# ```python
# census_bonus = Table.read_table('census_bonus.csv').group(['Year','County'],sum)

# %%
census_bonus = Table.read_table('census_bonus.csv').group([...],...)
census_bonus.show(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 census_bonus = Table.read_table('census_bonus.csv').group([...],...)
#       2 census_bonus.show(5)
#
# File ~/Desktop/ecc-biology/.venv/lib/python3.14/site-packages/datascience/tables.py:1553, in Table.group(self, column_or_label, collect)
#    1550 # Assume that a call to group with a list of labels is a call to groups
#    1551 if _util.is_non_string_iterable(column_or_label) and \
#    1552         len(column_or_label) != self._num_rows:
# -> 1553     return self.groups(column_or_label, collect)
#    1555 self = self.copy(shallow=True)
#    1556 collect = _zero_on_type_error(collect)
#
# File ~/Desktop/ecc-biology/.venv/lib/python3.14/site-packages/datascience/tables.py:1638, in Table.groups(self, labels, collect)
#    1635 if not _util.is_non_string_iterable(labels):
#    1636     return self.group(labels, collect=collect)
# -> 1638 collect = _zero_on_type_error(collect)
#    1639 columns = []
#    1640 labels = self._as_labels(labels)
#
# File ~/Desktop/ecc-biology/.venv/lib/python3.14/site-packages/datascience/tables.py:5830, in _zero_on_type_error(column_fn)
#    5828     return column_fn
#    5829 if not callable(column_fn):
# -> 5830     raise TypeError('column functions must be callable')
#    5831 @functools.wraps(column_fn)
#    5832 def wrapped(column):
#    5833     try:
#
# TypeError: column functions must be callable

# %% [markdown]
# ### 6.2 Guided exploration with `census_bonus`
#
# We’ll walk through some specific steps.
#
# #### Step 1 – Pick one county and look at its rows
#
# Use the code cell below to filter to a single county (for example, `Alameda County`) across years and display the first few rows.

# %%
# Step 1: filter to a single county (you can change the name)
county_name = 'Alameda County'  # note: match the exact spelling from the table
census_county = census_bonus.where('County', county_name)
census_county.show(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # Step 1: filter to a single county (you can change the name)
#       2 county_name = 'Alameda County'  # note: match the exact spelling from the table
# ----> 3 census_county = census_bonus.where('County', county_name)
#       4 census_county.show(5)
#
# NameError: name 'census_bonus' is not defined

# %% [markdown]
# #### Step 2 – Plot **total population** vs. year
#
# Use the built‑in `Table.plot` method to make a simple line plot of total population over time for that county.

# %%
# Step 2: plot total population vs year for that county
# %matplotlib inline
census_county.plot('Year', 'Total_Population sum')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Step 2: plot total population vs year for that county
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 census_county.plot('Year', 'Total_Population sum')
#
# NameError: name 'census_county' is not defined

# %% [markdown]
# ### Step 3 – Focus on one race group
#
# Choose one of the race columns (for example, `Asian Male sum` + `Asian Female sum`) and make a plot that shows how that sub‑population changes over time. Fill in the ... to execute the code.
#
# Look back at the table to see column names that should fill in the '....'
#
# If you are having trouble there is an example of what the code would look like for the Asian population if you click on 'HINT' below.
#
# <details>
# <summary><strong>HINT:</strong></summary>
#
# ```python
# asian_total = census_county.select('Year', 'Asian Male sum', 'Asian Female sum')
#
# asian_total = asian_total.with_column(
#     'Asian total',
#     asian_total.column('Asian Male sum') + asian_total.column('Asian Female sum')
# )
#
# asian_total.select('Year', 'Asian total').plot('Year')
# plt.show()

# %%
# Step 3: plot one race group vs year
race_total = census_county.select('Year', '....', '.....')
race_total = race_total.with_column(
    'race total',
    race_total.column('....') + race_total.column('...')
)

race_total.select('Year', 'race total').plot('Year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Step 3: plot one race group vs year
# ----> 2 race_total = census_county.select('Year', '....', '.....')
#       3 race_total = race_total.with_column(
#       4     'race total',
#       5     race_total.column('....') + race_total.column('...')
#       6 )
#       8 race_total.select('Year', 'race total').plot('Year')
#
# NameError: name 'census_county' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ### 6.3 Interactive: race totals by county and year
#
# Use the widget below to compare **race total** (male + female) to each **individual** sex column over time. Choose **All counties (average)** to see the **average race total per year** (and average male / female) across California counties, or pick a single county to match the plots above.

# %%
import importlib
import widgets

importlib.reload(widgets)
widgets.census_race_totals_widget()
# Out:
# interactive(children=(Dropdown(description='County', index=1, layout=Layout(width='420px'), options=('All coun…

# %% [markdown]
# ### 6.4 Compare multiple whole-race groups
#
# Each line is **one race total** (male + female combined), not separate sex columns. Use the **checkboxes** to select multiple races and overlay them on the same graph.
#
# The graph also includes one extra dashed black line showing the **overall average across all races** for the selected county.

# %%
import importlib
import widgets

importlib.reload(widgets)
widgets.census_race_multiselect_widget()
# Out:
# VBox(children=(HBox(children=(Dropdown(description='County', index=1, layout=Layout(width='420px'), options=('…

# %% [raw]
# # BEGIN QUESTION
# name: q7
# manual: true

# %% [markdown]
# ### Discussion Question 7:
#
# **Using the census exploration plots and widgets above, choose one county and observe how different race groups and total population change over time.**
#
# 1. **What demographic trends or population shifts do you notice in your chosen county?**
# 2. **How might demographic changes and population density in a county influence healthcare resource planning, community health needs, or the spread and management of infectious diseases like MRSA?**

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# REPLACE THIS TEXT WITH YOUR RESPONSE
# <br> [Note: double click on the cell, type in your response, and run the cell to save your work]

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# ## Submission Instructions
#
# Before downloading your notebook as a PDF, make sure you have:
# 1. **Run all cells** in order from top to bottom so all your code outputs, plots, and written responses are visible.
# 2. **Saved your notebook** by clicking **File → Save Notebook** (or pressing `Cmd + S` / `Ctrl + S`).
#
#
# ### How to Download as PDF in JupyterLab / JupyterHub:
#
# Save and Export Notebook As PDF
# 1. In the top menu bar, click **File**.
# 2. Hover over **Save and Export Notebook As...** (or **Download as** depending on your Jupyter version).
# 3. Click **PDF** (or **PDF via LaTeX / HTML**).
# 4. Your PDF file will download automatically to your computer's Downloads folder.
#
#
# ### Turn In Your Assignment:
# Once you have downloaded your PDF, submit it to **Canvas** under the corresponding assignment.
