# %%
import pandas as pd

# %%
#cd EnviroScreen4
CES4 = pd.read_excel("calenviroscreen40resultsdatadictionary_F_2021.xlsx", sheet_name='CES4.0FINAL_results')

# %%
CES4
# Out:
#       Census Tract  Total Population California County    ZIP  \
# 0       6019001100              2780           Fresno   93706
# 1       6077000700              4680       San Joaquin  95206
# 2       6037204920              2751       Los Angeles  90023
# 3       6019000700              3664           Fresno   93706
# 4       6019000200              2689           Fresno   93706
# ...            ...               ...               ...    ...
# 8030    6107004000               582           Tulare   93257
# 8031    6109985202              2509         Tuolumne   95327
# 8032    6111001206               778          Ventura   93001
# 8033    6111003012               675          Ventura   93036
# 8034    6111980000               118          Ventura      61
#
#                      Approximate Location   Longitude   Latitude  \
# 0                                  Fresno -119.781696  36.709695
# 1                                Stockton -121.287873  37.943173
# 2                             Los Angeles -118.197497  34.017500
# 3                                  Fresno -119.827707  36.734535
# 4                                  Fresno -119.805504  36.735491
# ...                                   ...         ...        ...
# 8030                          Porterville -118.983849  36.038061
# 8031  Unincorporated Tuolumne County area -120.537071  37.891939
# 8032   Unincorporated Ventura County area -119.371944  34.343903
# 8033                               Oxnard -119.180105  34.235076
# 8034   Unincorporated Ventura County area -119.503588  33.255655
#
#       CES 4.0 Score  CES 4.0 Percentile  CES 4.0 Percentile Range  ...  \
# 0         93.183570          100.000000  95-100% (highest scores)  ...
# 1         86.653790           99.987393  95-100% (highest scores)  ...
# 2         82.393909           99.974786  95-100% (highest scores)  ...
# 3         81.327940           99.962179  95-100% (highest scores)  ...
# 4         80.745476           99.949571  95-100% (highest scores)  ...
# ...             ...                 ...                       ...  ...
# 8030            NaN                 NaN                       NaN  ...
# 8031            NaN                 NaN                       NaN  ...
# 8032            NaN                 NaN                       NaN  ...
# 8033            NaN                 NaN                       NaN  ...
# 8034            NaN                 NaN                       NaN  ...
#
#       Linguistic Isolation Pctl  Poverty  Poverty Pctl  Unemployment  \
# 0                     79.374746     76.0     98.919598          12.8
# 1                     95.533902     73.2     98.391960          19.8
# 2                     81.553661     62.6     93.391960           6.4
# 3                     78.711598     65.7     95.351759          15.7
# 4                     86.561104     72.7     98.304020          13.7
# ...                         ...      ...           ...           ...
# 8030                        NaN     79.6     99.422111           NaN
# 8031                        NaN      NaN           NaN           NaN
# 8032                        NaN     17.1     27.349246           NaN
# 8033                  99.553390     96.7    100.000000           NaN
# 8034                        NaN      NaN           NaN           NaN
#
#       Unemployment Pctl  Housing Burden  Housing Burden Pctl  Pop. Char.   \
# 0             93.831338            30.3            91.039290    93.155109
# 1             99.206143            31.2            92.281369    93.165408
# 2             61.530453            20.3            63.967047    83.751814
# 3             97.345133            35.4            96.413181    94.641227
# 4             95.288912            32.7            94.157161    95.398873
# ...                 ...             ...                  ...          ...
# 8030                NaN             NaN                  NaN          NaN
# 8031                NaN             NaN                  NaN          NaN
# 8032                NaN            24.4            78.466413          NaN
# 8033                NaN             NaN                  NaN          NaN
# 8034                NaN             NaN                  NaN          NaN
#
#       Pop. Char. Score  Pop. Char. Pctl
# 0             9.663213        99.722642
# 1             9.664281        99.735250
# 2             8.687785        95.789208
# 3             9.817371        99.886536
# 4             9.895964        99.949571
# ...                ...              ...
# 8030               NaN              NaN
# 8031               NaN              NaN
# 8032               NaN              NaN
# 8033               NaN              NaN
# 8034               NaN              NaN
#
# [8035 rows x 58 columns]

# %%
# !ls
# Out:
# CES1-intro.ipynb
# CES2-CommColl.ipynb
# College_codes_EVDtype.xlsx
# Envroscreen4.ipynb
# calenviroscreen40resultsdatadictionary_F_2021.xlsx
# calenviroscreen40shpf2021shp

# %%
CollegeCodes= pd.read_excel("College_codes_EVDtype.xlsx")
CollegeCodes
# Out:
#       OPEID                    College         City State    Zip  yrs  EVDCode
# 0    111100      ALLAN HANCOCK COLLEGE  SANTA MARIA    CA  93454    2        1
# 1    111300    ANTELOPE VALLEY COLLEGE    LANCASTER    CA  93534    2        1
# 2    111500       ARMSTRONG UNIVERSITY     BERKELEY    CA  94704    4        4
# 3    111600  ART CENTER COLLEGE OF DES     PASADENA    CA  91103    4        4
# 4    111700   AZUSA PACIFIC UNIVERSITY        AZUSA    CA  91702    4        4
# ..      ...                        ...          ...   ...    ...  ...      ...
# 168  133800        WEST VALLEY COLLEGE     SARATOGA    CA  95070    2        1
# 169  134100           WESTMONT COLLEGE  SNTA BARBRA    CA  93108    4        4
# 170  134200           WHITTIER COLLEGE     WHITTIER    CA  90608    4        4
# 171  134300        WOODBURY UNIVERSITY      BURBANK    CA  91510    4        4
# 172  134400               YUBA COLLEGE   MARYSVILLE    CA  95901    2        1
#
# [173 rows x 7 columns]

# %%
#count if EVDCode = 1
CollegeCodes['EVDCode'].value_counts()
# Out:
# 1    81
# 4    63
# 2    20
# 3     9
# Name: EVDCode, dtype: int64

# %%
#drop rows where EVDCode = 4
CollegeCodes_Public = CollegeCodes[CollegeCodes['EVDCode'] != 4]

# %%
#merge CollegeCodes_Public with CES4
CES4_Public = pd.merge(CES4, CollegeCodes_Public, how='inner', left_on='ZIP', right_on='Zip')

# %%
# Find the most polluted zip codes and show the college there
CES4_Public.sort_values(by='CES 4.0 Score', ascending=False).head(10)
# Out:
#     Census Tract  Total Population California County    ZIP  \
# 0     6037542402              3306       Los Angeles  90221
# 11    6099003700              4669       Stanislaus   95380
# 1     6037542200              7155       Los Angeles  90221
# 2     6037542401              4735       Los Angeles  90221
# 21    6037294701              3099       Los Angeles  90744
# 12    6099003802              5339       Stanislaus   95380
# 36    6071004900              7113    San Bernardino  92410
# 46    6047001302              2873           Merced   95340
# 47    6047001301              2662           Merced   95340
# 54    6019006802              3339           Fresno   93654
#
#                      Approximate Location   Longitude   Latitude  \
# 0                                 Compton -118.212413  33.881969
# 11  Unincorporated Stanislaus County area -120.883606  37.464793
# 1                                 Compton -118.197151  33.886893
# 2                                 Compton -118.210904  33.892362
# 21                            Los Angeles -118.254908  33.778016
# 12                                Turlock -120.857699  37.486126
# 36                         San Bernardino -117.316879  34.100314
# 46                                 Merced -120.478191  37.304035
# 47                                 Merced -120.491786  37.307192
# 54      Unincorporated Fresno County area -119.497435  36.599505
#
#     CES 4.0 Score  CES 4.0 Percentile  CES 4.0 Percentile Range  ...  \
# 0       80.708813           99.936964  95-100% (highest scores)  ...
# 11      75.309718           99.697428  95-100% (highest scores)  ...
# 1       73.920598           99.571357  95-100% (highest scores)  ...
# 2       73.163005           99.483106  95-100% (highest scores)  ...
# 21      71.294434           99.268785  95-100% (highest scores)  ...
# 12      66.708770           98.348462  95-100% (highest scores)  ...
# 36      66.664401           98.310640  95-100% (highest scores)  ...
# 46      66.503809           98.247605  95-100% (highest scores)  ...
# 47      66.405061           98.209783  95-100% (highest scores)  ...
# 54      66.353330           98.171962  95-100% (highest scores)  ...
#
#     Pop. Char.   Pop. Char. Score  Pop. Char. Pctl   OPEID  \
# 0     83.366150          8.647779        95.461422  118800
# 11    81.371527          8.440872        93.872920  115700
# 1     84.834272          8.800071        96.520424  118800
# 2     88.461525          9.176335        98.676248  118800
# 21    81.462638          8.450323        93.986384  122400
# 12    80.889624          8.390883        93.381241  115700
# 36    91.411297          9.482323        99.432678  127200
# 46    96.401800         10.000000       100.000000  123700
# 47    87.784501          9.106106        98.323248  123700
# 54    90.407394          9.378185        99.256178  130800
#
#                       College         City  State    Zip  yrs  EVDCode
# 0        COMPTON CMTY COLLEGE      COMPTON     CA  90221    2        1
# 11   CALIF ST UNIV STANISLAUS      TURLOCK     CA  95380    4        2
# 1        COMPTON CMTY COLLEGE      COMPTON     CA  90221    2        1
# 2        COMPTON CMTY COLLEGE      COMPTON     CA  90221    2        1
# 21  LOS ANGELES HARBOR COLLEG   WILMINGTON     CA  90744    2        1
# 12   CALIF ST UNIV STANISLAUS      TURLOCK     CA  95380    4        2
# 36  SAN BERNARDINO VALLEY COL  SN BERNRDNO     CA  92410    2        1
# 46             MERCED COLLEGE       MERCED     CA  95340    2        1
# 47             MERCED COLLEGE       MERCED     CA  95340    2        1
# 54            REEDLEY COLLEGE      REEDLEY     CA  93654    2        1
#
# [10 rows x 65 columns]

# %%
# Find the least polluted zip codes and show the college there
CES4_Public.sort_values(by='CES 4.0 Score', ascending=True).head(10)
# Out:
#      Census Tract  Total Population California County    ZIP  \
# 673    6085507302              2892       Santa Clara  95070
# 666    6087122002              3253        Santa Cruz  95003
# 676    6041119100              4983            Marin   94904
# 686    6085510400              3705       Santa Clara  94022
# 641    6013326000              3810      Contra Costa  94523
# 656    6065045115              1890        Riverside   92260
# 679    6067000200              3755       Sacramento   95819
# 571    6081605800              2572         San Mateo  94402
# 681    6081611500              2836         San Mateo  94027
# 672    6085507301              6602       Santa Clara  95070
#
#                        Approximate Location   Longitude   Latitude  \
# 673  Unincorporated Santa Clara County area -122.029224  37.238282
# 666                              Day Valley -121.865486  37.022755
# 676                               Kentfield -122.553276  37.943546
# 686                               Los Altos -122.107654  37.391307
# 641                           Reliez Valley -122.088536  37.937267
# 656                             Palm Desert -116.387138  33.704824
# 679                              Sacramento -121.440758  38.574059
# 571                               San Mateo -122.345175  37.568018
# 681                                Atherton -122.184961  37.467542
# 672                                Saratoga -122.007886  37.258968
#
#      CES 4.0 Score  CES 4.0 Percentile CES 4.0 Percentile Range  ...  \
# 673       1.305676            0.050429     1-5% (lowest scores)  ...
# 666       2.174766            0.315179     1-5% (lowest scores)  ...
# 676       2.179612            0.327786     1-5% (lowest scores)  ...
# 686       3.166595            0.769037     1-5% (lowest scores)  ...
# 641       3.177840            0.781644     1-5% (lowest scores)  ...
# 656       3.550277            1.059002     1-5% (lowest scores)  ...
# 679       3.771116            1.159859     1-5% (lowest scores)  ...
# 571       3.799035            1.185073     1-5% (lowest scores)  ...
# 681       3.873313            1.336359     1-5% (lowest scores)  ...
# 672       3.911930            1.374181     1-5% (lowest scores)  ...
#
#      Pop. Char.   Pop. Char. Score  Pop. Char. Pctl   OPEID  \
# 673     4.685946          0.486085         0.088250  133800
# 666     7.964212          0.826148         0.554715  112400
# 676     7.546651          0.782833         0.428643  117800
# 686     7.178839          0.744679         0.353001  119900
# 641    13.720003          1.423210         2.887040  119100
# 656    17.271309          1.791596         5.408472  118200
# 679     9.760934          1.012526         0.995966  115000
# 571     8.981814          0.931706         0.781644  118100
# 681     8.370139          0.868256         0.605144  123600
# 672    11.048506          1.146089         1.386788  133800
#
#                       College         City  State    Zip  yrs  EVDCode
# 673       WEST VALLEY COLLEGE     SARATOGA     CA  95070    2        1
# 666          CABRILLO COLLEGE        APTOS     CA  95003    2        1
# 676                COLL MARIN    KENTFIELD     CA  94904    2        1
# 686          FOOTHILL COLLEGE  L ALTOS HLS     CA  94022    2        1
# 641     DIABLO VALLEY COLLEGE   PLEASNT HL     CA  94523    2        1
# 656               COLL DESERT  PALM DESERT     CA  92260    2        1
# 679  CALIF ST UNIV SACRAMENTO   SACRAMENTO     CA  95819    4        2
# 571            COLL SAN MATEO    SAN MATEO     CA  94402    2        1
# 681             MENLO COLLEGE     ATHERTON     CA  94027    4        1
# 672       WEST VALLEY COLLEGE     SARATOGA     CA  95070    2        1
#
# [10 rows x 65 columns]

# %%
# what is the score at El Camino College
CES4_Public[CES4_Public['College'] == 'EL CAMINO COLLEGE']
# Out:
#      Census Tract  Total Population California County    ZIP  \
# 343    6037603702              4777       Los Angeles  90506
#
#     Approximate Location   Longitude   Latitude  CES 4.0 Score  \
# 343         Alondra Park -118.339382  33.882996      38.318928
#
#      CES 4.0 Percentile CES 4.0 Percentile Range  ...  Pop. Char.   \
# 343           72.655068                   70-75%  ...    57.252798
#
#      Pop. Char. Score  Pop. Char. Pctl   OPEID            College  \
# 343          5.938976        61.296016  119700  EL CAMINO COLLEGE
#
#             City  State    Zip  yrs  EVDCode
# 343  VIA TORRANC     CA  90506    2        1
#
# [1 rows x 65 columns]
